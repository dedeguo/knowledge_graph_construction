# %% [markdown]
# <a href="https://colab.research.google.com/github/dedeguo/knowledge_graph_construction/blob/master/memNetwork_and_BiLSTM_CRF_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive"

os.chdir(path)
os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ['毕业论文',
#  'chen',
#  'Core Libraries Group.pdf',
#  'Colab',
#  'Colab Notebooks',
#  'AAA-毕业论文2-28.docx',
#  '测试绘图.gdraw']

# %% [markdown]
# https://drive.google.com/file/d/1QXFqD6Qm8H9bRSbw7yZIgTGxD0O6ejUq/view?usp=sharing

# %%
# !ls
# Out:
#  chende_ner_lab.ipynb
#  cluedata-ner-roberta_wwm_large.ipynb
#  CLUE-dataset-lab.ipynb
#  roberta_zh_L-6-H-768_A-12.zip
# '“TensorFlow 2.0 Handbook - TPU Example”的副本'
#  Untitled0.ipynb
#  人民日报数据集实体识别实验.ipynb

# %%
# !git clone https://github.com/Vipning/RoBERTa-base-Memory-network.git
# Out:
# Cloning into 'RoBERTa-base-Memory-network'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 80 (delta 14), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (80/80), done.
# Checking out files: 100% (48/48), done.

# %%
# %cd RoBERTa-base-Memory-network/bert-crf-mn/bert/
# Out:
# /content/drive/My Drive/毕业论文/RoBERTa-base-Memory-network/bert-crf-mn/bert

# %%
# !unzip roberta_zh_L-6-H-768_A-12.zip
# Out:
# Archive:  roberta_zh_L-6-H-768_A-12.zip
#   inflating: bert_config.json
#   inflating: bert_model.ckpt.data-00000-of-00001
#   inflating: bert_model.ckpt.index
#   inflating: bert_model.ckpt.meta
#   inflating: checkpoint
#   inflating: vocab.txt

# %%
# !ls
# Out:
# attention.py  data		 model.py	  run_bert.py
# bert	      data_processor.py  ner_metrics.py   tokenization.py
# common.py     dataset_loader.py  nn_utils.py	  utils_ner.py
# config.py     modeling.py	 optimization.py

# %%
# !pip install tensorflow-gpu==1.15

# %% [markdown]
# ###上传文件

# %%
from google.colab import files
files.upload()
# choose the file on your computer to upload it then

# %%
# !rm -rf bert-crf-mn

# %%
# !cp -Rf bert-crf-mn/*  /content/bert-crf-mn

# %%
# !python run_bert.py --do_train
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/bert-crf-mn/bert/optimization.py:73: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/bert-crf-mn/common.py:45: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 05/10/2020 07:18:44 - WARNING - tensorflow -   From /content/bert-crf-mn/common.py:45: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# ...

# %% [markdown]
# #bilstm-crf模型实验

# %%
# !ls
# Out:
# bert-crf-mn  bilstm-crf  README.md  roberta_zh_L-6-H-768_A-12.zip

# %%
! cp -Rf bilstm-crf/* /content/

# %%
# !ls
# Out:
# bert-crf-mn	   dataset_loader.py	  outputs	   utils_ner.py
# common.py	   download_clue_data.py  requirement.txt  vocabulary.py
# config.py	   drive		  rnncell.py
# data_processor.py  model.py		  run_lstm_crf.py
# dataset		   ner_metrics.py	  sample_data

# %%
# !python run_lstm_crf.py --do_train
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/common.py:45: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 05/10/2020 10:49:17 - WARNING - tensorflow -   From /content/common.py:45: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 05/10/2020 10:49:17 - INFO - root -   Loading features from cached file dataset/cluener/cached_crf-train_bilstm_crf_ner
# WARNING:tensorflow:From run_lstm_crf.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...
